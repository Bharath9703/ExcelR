# %% [markdown]
# 1.Prime numbers

# %%
def is_prime(n):
    """Check if a number is prime."""
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# %%
# Test the function
number = 29
print(f"Is {number} a prime number? {is_prime(number)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4ea1c8d18b6f> in <cell line: 3>()
#       1 # Test the function
#       2 number = 29
# ----> 3 print(f"Is {number} a prime number? {is_prime(number)}")
#
# NameError: name 'is_prime' is not defined

# %% [markdown]
# Exercise 2: Product of Random Numbers

# %%
import random

def check_product():
  num1 = random.randint(1, 10)
  num2 = random.randint(1, 10)
  correct_answer = num1 * num2

  user_answer = int(input(f"What is the product of {num1}*{num2}? "))

  if user_answer == correct_answer:
    print("Correct!")
  else:
    print(f"Wrong! The correct answer is {correct_answer}.")

# Call  function
check_product()
# Out:
# What is the product of 4*7? 28
# Correct!

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers

# %%
# Choosing even numbers for this exercise
print("Squares of even numbers from 100 to 200:")
for number in range(100, 201):
    if number % 2 == 0:  # Check if the number is even
        print(f"{number}^2 = {number ** 2}")
# Out:
# Squares of even numbers from 100 to 200:
# 100^2 = 10000
# 102^2 = 10404
# 104^2 = 10816
# 106^2 = 11236
# 108^2 = 11664
# 110^2 = 12100
# 112^2 = 12544
# 114^2 = 12996
# 116^2 = 13456
# 118^2 = 13924
# 120^2 = 14400
# 122^2 = 14884
# 124^2 = 15376
# 126^2 = 15876
# 128^2 = 16384
# 130^2 = 16900
# 132^2 = 17424
# 134^2 = 17956
# 136^2 = 18496
# 138^2 = 19044
# 140^2 = 19600
# 142^2 = 20164
# 144^2 = 20736
# 146^2 = 21316
# 148^2 = 21904
# 150^2 = 22500
# 152^2 = 23104
# 154^2 = 23716
# 156^2 = 24336
# 158^2 = 24964
# 160^2 = 25600
# 162^2 = 26244
# 164^2 = 26896
# 166^2 = 27556
# 168^2 = 28224
# 170^2 = 28900
# 172^2 = 29584
# 174^2 = 30276
# 176^2 = 30976
# 178^2 = 31684
# 180^2 = 32400
# 182^2 = 33124
# 184^2 = 33856
# 186^2 = 34596
# 188^2 = 35344
# 190^2 = 36100
# 192^2 = 36864
# 194^2 = 37636
# 196^2 = 38416
# 198^2 = 39204
# 200^2 = 40000

# %% [markdown]
# Exercise 4: Word counter

# %%
def word_counter(input_text):
    """Count the number of occurrences of each word in the given text."""
    # Split the text into words and initialize a dictionary to hold the counts
    words = input_text.split()
    word_count = {}

    for word in words:
        word_count[word] = word_count.get(word, 0) + 1

    return word_count

# %%
# Example usage of the word_counter function
input_text = "This is a sample text. This text will be used to demonstrate the word counter."
word_counts = word_counter(input_text)

# Printing the word counts
print("\nWord counts:")
for word, count in word_counts.items():
    print(f"'{word}': {count}")
# Out:
# Word counts:
# 'This': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text.': 1
# 'text': 1
# 'will': 1
# 'be': 1
# 'used': 1
# 'to': 1
# 'demonstrate': 1
# 'the': 1
# 'word': 1
# 'counter.': 1

# %% [markdown]
# Exercise 5: Check for Palindrome

# %%
def is_palindrome(input_string):
    """Check if the given string is a palindrome."""
    # Normalize the string: remove spaces, punctuation and convert to lowercase
    normalized_string = ''.join(char.lower() for char in input_string if char.isalnum())
    # Check if the string reads the same forwards and backwards
    return normalized_string == normalized_string[::-1]


# Example usage of the is_palindrome function
test_strings = ["racecar", "12121", "hello"]
print("\nPalindrome checks:")
for test_string in test_strings:
    result = is_palindrome(test_string)
    print(f"'{test_string}': {result}")
# Out:
# Palindrome checks:
# 'racecar': True
# '12121': True
# 'hello': False
